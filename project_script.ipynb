# %% [markdown]
# # Starr Project
# #### John R. Starr; jrs294@pitt.edu
#
# The data is split into two folders/files, en/TEP.xml and fa/TEP.xml. Let's import what we need to properly search through this data:

# %%
import pandas as pd
import numpy as np
import nltk
import postagger
import xml.etree.ElementTree as ET
from lxml import etree

# %% [markdown]
# Building a parser that works for xml:

# %%
parser_test = etree.XMLParser()
tree_eng = ET.parse('TEP/raw/en/TEP.xml', parser = parser_test)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\16starjo\Documents\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-2-2f2c1bb1b0f3>", line 2, in <module>
#     tree_eng = ET.parse('TEP/raw/en/TEP.xml', parser = parser_test)
#
#   File "C:\Users\16starjo\Documents\Anaconda3\lib\xml\etree\ElementTree.py", line 1197, in parse
#     tree.parse(source, parser)
#
#   File "C:\Users\16starjo\Documents\Anaconda3\lib\xml\etree\ElementTree.py", line 604, in parse
#     parser.feed(data)
#
#   File "src/lxml/parser.pxi", line 1242, in lxml.etree._FeedParser.feed
#
#   File "src/lxml/parser.pxi", line 1364, in lxml.etree._FeedParser.feed
#
#   File "src/lxml/xmlerror.pxi", line 592, in lxml.etree._getThreadErrorLog
#
#   File "src/lxml/parser.pxi", line 601, in lxml.etree._ParserContext._handleParseResultDoc
#
#   File "src/lxml/parser.pxi", line 711, in lxml.etree._handleParseResult
#
#   File "src/lxml/parser.pxi", line 640, in lxml.etree._raiseParseError
#
#   File "<string>", line 86381
# XMLSyntaxError: Char 0x0 out of allowed range, line 86381, column 25

# %% [markdown]
# Hmmm... After some preliminary efforts in building trees, I found that some of my data has corrupted characters (or at least something along those lines). An example of one of these encoding errors can be found in the following sentence: <s id="86377">simple caf oronary . freak show choked to death .</s> When opened in Notepad++, the space between "caf" and "oronary" is the abbreviation NUL highlighted in black. Other problems occur later in the dataset. I am still in the process of figuring out what these characters are, but for now, we'll set the parser to the following:

# %%
parser_full = etree.XMLParser(recover = True)
tree_eng = ET.parse('TEP/raw/en/TEP.xml', parser = parser_full)

# %% [markdown]
# Now, let's build the root and see how our data is structured. I've looked through the XML file and noticed that there is a bit of a heading that looks like this (I have added spaces between the greater/less than symbols so that it remains visible in this file):
#
# < ?xml version="1.0" encoding="utf-8"? >
# < letsmt version="1.0" >
# < head >< /head >
#
# After that, we have the body character, followed by a sentence. So, we'll use .findall() to start where we want it to start, and hopefully we'll be able to get an idea of what our data looks like:

# %%
root_eng = tree_eng.getroot()
root_eng.items()
for item in root_eng.findall('./body/s')[:5]:
    print(item.text)
    #print(dir(item))
    print(item.values())
    print(item.items())
# Out:
# raspy breathing .
# ['1']
# [('id', '1')]
# dad .
# ['2']
# [('id', '2')]
# maybe its the wind .
# ['3']
# [('id', '3')]
# no .
# ['4']
# [('id', '4')]
# stop please stop .
# ['5']
# [('id', '5')]

# %% [markdown]
# It looks like our data uses the ID number to mark what text comes after it. This works well, as we'll be able to match up the keys between the two files to combine them! Let's create a test dictionary in which the key is the item and the text is the value, replacing all extraneous information:

# %%
eng_lines_test = {}
for item in root_eng.findall('./body/s')[:5]:
     eng_lines_test[int(str(item.values()).replace(',', '').replace("['", '').replace("']", ''))] = str(item.text.replace(',', '').replace(' .', ''))

# %%
eng_lines_test.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
eng_lines_test.values()
# Out:
# dict_values(['raspy breathing', 'dad', 'maybe its the wind', 'no', 'stop please stop'])

# %% [markdown]
# Awesome! Let's do the same for the Farsi text as well!

# %%
tree_far = ET.parse('TEP/raw/fa/TEP.xml', parser = parser_full)

# %%
far_lines_test = {}
root_far = tree_far.getroot()
for item in root_far.findall('./body/s')[:5]:
    far_lines_test[int(str(item.values()).replace(',', '').replace("['", '').replace("']", ''))] = str(item.text.replace(',', '').replace(' .', ''))

# %%
far_lines_test.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
far_lines_test.values()
# Out:
# dict_values(['صداي خر خر', 'پدر', 'شايد صداي باد باشه', 'نه', 'دست نگه داريد خواهش ميکنم دست نگه داريد'])

# %% [markdown]
# All in the clear! Now, let's combine the two into a single DataFrame object!

# %%
test_DF = pd.Series(eng_lines_test).to_frame('eng').join(pd.Series(far_lines_test).to_frame('far'), how='outer')
test_DF
# Out:
#                   eng                                      far
# 1     raspy breathing                               صداي خر خر
# 2                 dad                                      پدر
# 3  maybe its the wind                       شايد صداي باد باشه
# 4                  no                                       نه
# 5    stop please stop  دست نگه داريد خواهش ميکنم دست نگه داريد

# %% [markdown]
# It worked! Yay! Let's try the whole thing now:

# %%
eng_lines = {}
for item in root_eng.findall('./body/s'):
     eng_lines[int(str(item.values()).replace(',', '').replace("['", '').replace("']", ''))] = str(item.text.replace(',', '').replace(' .', ''))
print(len(eng_lines))
# Out:
# 86377

# %%
far_lines = {}
for item in root_far.findall('./body/s'):
     far_lines[int(str(item.values()).replace(',', '').replace("['", '').replace("']", ''))] = str(item.text.replace(',', '').replace(' .', ''))
print(len(far_lines))
# Out:
# 612086

# %% [markdown]
# Wait a second... these numbers don't line up! What's going on here? The two XML files are the same length. Let's see what the DF would look like, plus a general description of the files:

# %%
sample_full_DF = pd.Series(eng_lines).to_frame('Eng').join(pd.Series(far_lines).to_frame('Far'), how='outer')
sample_full_DF.index.name = 'ID'
sample_full_DF
# Out:
#                                                       Eng  \
# ID
# 1                                         raspy breathing
# 2                                                     dad
# 3                                      maybe its the wind
# 4                                                      no
# 5                                        stop please stop
# 6         you have a week  evans then well burn the house
# 7                                                 william
# 8                                    god damn it  william
# 9                               god damn it put that down
# 10                                                 let go
# 11                             its the last feed weve got
# 12                                  ill take care of this
# 13                                           no  you wont
# 14      herds over the ridge by now you go get cleaned up
# 15                                    you lied to me  dan
# 16       you told me we made payments to hollander we did
# 17      so  how do you think we bought feed  alice thr...
# 18      i had a choice between our family and paying t...
# 19               were supposed to make decisions together
# 20                 would you have made anything different
# 21      alice  we cant make it rain together turn the ...
# 22      we cant stop hollander from selling our land t...
# 23      its too bad the doctors at the aid station did...
# 24                           stop looking at me like that
# 25      are you going to tell the marshal what those m...
# 26                        marshal aint doing shit william
# 27      first thing  mark im going to take you boys we...
# 28                         what are you going to do there
# 29          im going to tell hollander to make this right
# 30             im going to tell him to pay for a new barn
# ...                                                   ...
# 612057                                                NaN
# 612058                                                NaN
# 612059                                                NaN
# 612060                                                NaN
# 612061                                                NaN
# 612062                                                NaN
# 612063                                                NaN
# 612064                                                NaN
# 612065                                                NaN
# 612066                                                NaN
# 612067                                                NaN
# 612068                                                NaN
# 612069                                                NaN
# 612070                                                NaN
# 612071                                                NaN
# 612072                                                NaN
# 612073                                                NaN
# 612074                                                NaN
# 612075                                                NaN
# 612076                                                NaN
# 612077                                                NaN
# 612078                                                NaN
# 612079                                                NaN
# 612080                                                NaN
# 612081                                                NaN
# 612082                                                NaN
# 612083                                                NaN
# 612084                                                NaN
# 612085                                                NaN
# 612086                                                NaN
#
#                                                       Far
# ID
# 1                                              صداي خر خر
# 2                                                     پدر
# 3                                      شايد صداي باد باشه
# 4                                                      نه
# 5                 دست نگه داريد خواهش ميکنم دست نگه داريد
# 6       اوانز تو فقط يک هفته وقت داري وگرنه خونتو خواه...
# 7                                                  ويليام
# 8                                          لعنتي ويليام 8
# 9                               لعنت به تو اونو بذار زمين
# 10                                               بذار برم
# 11                    اين آخرين علوفه اي بود که ما داشتيم
# 12                           من خودم اين کارو انجام ميدهم
# 13                                           نه تو نميکني
# 14        گله را آوردم بيرون الان تو برو اونجا را تميز کن
# 15                                  تو به من دروغ گفتي دن
# 16      تو به من گفتي قرضمونو به هلندر پرداخت کرديم ما...
# 17      خب پس تو فکر ميکني ما چطوري علوفه خريديم سه ما...
# 18      من فقط يک انتخاب بين خانوادم و پرداخت قرض اونا...
# 19                      ما قرار بود تصميماتو با هم بگيريم
# 20                          مگه تو تصميمه ديگه اي ميگرفتي
# 21      آليس مادوباره ميتونيم همه چي را دوباره جمع کني...
# 22      ما هم نميتونيم جلوي هلندر را از فروش زمينمون ب...
# 23      مشکل اينجاست که دکترها در درمانگاه کار زيادي ب...
# 24                                 اينجوري به من نگاه نکن
# 25         تو ميخواي به مارشال بگي که اون آدما چيکار کردن
# 26                   مارشال هيچ کاري واسمون نميکنه ويليام
# 27      مارک اول اينکه من ميخوام شما پسرهارو با خودم ب...
# 28                              تو ميخواي اونجا چيکار کني
# 29                     من به هلندر ميگم که اينو درستش کنه
# 30                     من بهش ميگم پول يک اسطبل جديدو بده
# ...                                                   ...
# 612057                                          کج و معوج
# 612058                                            فلز روي
# 612059                                       قطب پيل ولتا
# 612060                                       اکسيد دو زنگ
# 612061                                           بشکل روي
# 612062                                         قلمزني روي
# 612063                                       شبيه فلز روي
# 612064                                              روئين
# 612065                                     صدائي شبيه جيغ
# 612066                                     جيغ شديد و تند
# 612067                                        قوم اسرائيل
# 612068                                        صهيون گرائي
# 612069                                      نهضت صهيونيسم
# 612070                                          صهيون گرا
# 612071                                           صهيونيست
# 612072                                           نيروفشار
# 612073                                       زيپ دار کردن
# 612074                                     رمز منطقه پستي
# 612075                                           زيب لباس
# 612076                                            زيب دار
# 612077                                         پر از وزوز
# 612078                                          طر سروصدا
# 612079                                            پر نيرو
# 612080                                             زودياک
# 612081                                       منطقه‌البروج
# 612082                                       دايره‌البروج
# 612083                                        حمره مغربيه
# 612084                                      انسان زنده شد
# 612085                                        مارخداگرائي
# 612086                                              مداري
#
# [612086 rows x 2 columns]

# %%
sample_full_DF.describe()
# Out:
#             Eng     Far
# count     86377  612086
# unique    80554  583981
# top     come on     بله
# freq         28    1596

# %% [markdown]
# It seems that there are _significantly_ less Enlish sentences. Let's see if we can examine the problem area by looking at sentences 86375 to 86400:

# %%
sample_full_DF.loc[86375:86400,"Eng":"Far"]
# Out:
#                                                      Eng  \
# ID
# 86375                                          hands off
# 86376  if you had your game faces on at the academy  ...
# 86377                                         simple caf
# 86378                                                NaN
# 86379                                                NaN
# 86380                                                NaN
# 86381                                                NaN
# 86382                                                NaN
# 86383                                                NaN
# 86384                                                NaN
# 86385                                                NaN
# 86386                                                NaN
# 86387                                                NaN
# 86388                                                NaN
# 86389                                                NaN
# 86390                                                NaN
# 86391                                                NaN
# 86392                                                NaN
# 86393                                                NaN
# 86394                                                NaN
# 86395                                                NaN
# 86396                                                NaN
# 86397                                                NaN
# 86398                                                NaN
# 86399                                                NaN
# 86400                                                NaN
#
#                                                      Far
# ID
# 86375                                          دست نزنيد
# 86376          اگه شما هم توي دانشكده بوديد ، مي فهميديد
# 86377                                        اون خفه شده
# 86378                                        سوالي داريد
# 86379            آزمايش از دهان نشون ميده گوشت خوك خورده
# 86380                                    در راهرو هم هست
# 86381          باشه ، بيا اين كارو بكنيم ، زود باش عزيزم
# 86382            هيچ علامتي از آسيب روي گلويش وجود نداره
# 86383             علائم درگيري نشون ميده كه اون خفه نشده
# 86384                                     اونو خفه كردند
# 86385                   خانم ها ، ما از اينجا موم گرفتيم
# 86386                                             آناناس
# 86387                             واكس سكسه ، بهترين نوع
# 86388               قاتل يک اسكي باز بوده از كجا ميدونيد
# 86389                      اون از كارت اعتباري براي ورود
# 86390                               به خونه استفاده كرده
# 86391                                     اسكي باز آشغال
# 86392  يه چاپ خارجي استفاده كرده ، كه در سال 1989 فرو...
# 86393                                يه نسخه از اون تنها
# 86394              در فونتانا در تابستان 2002 فروخته شده
# 86395                                     اختلاف وزن بين
# 86396                        طرف چپ و طرف راست وجود داره
# 86397               يه مشكل عضلاني كه سال پيش معالجه شده
# 86398                         خيلي خوب ، كي اين كارو كرد
# 86399       يه قاتل با يک زخم روي پاش كه اسكي باز هم هست
# 86400                                        نفرت انگيزه

# %% [markdown]
# It seems that the "weird" character that we thought we eliminated has actually blocked all the values after it... Going to have to fix that for the next progress report! For now, let's try processing the lines up until that point to prepare them for tagging.

# %%
sample_full_DF = sample_full_DF[sample_full_DF.Eng.notnull()]
sample_full_DF
# Out:
#                                                      Eng  \
# ID
# 1                                        raspy breathing
# 2                                                    dad
# 3                                     maybe its the wind
# 4                                                     no
# 5                                       stop please stop
# 6        you have a week  evans then well burn the house
# 7                                                william
# 8                                   god damn it  william
# 9                              god damn it put that down
# 10                                                let go
# 11                            its the last feed weve got
# 12                                 ill take care of this
# 13                                          no  you wont
# 14     herds over the ridge by now you go get cleaned up
# 15                                   you lied to me  dan
# 16      you told me we made payments to hollander we did
# 17     so  how do you think we bought feed  alice thr...
# 18     i had a choice between our family and paying t...
# 19              were supposed to make decisions together
# 20                would you have made anything different
# 21     alice  we cant make it rain together turn the ...
# 22     we cant stop hollander from selling our land t...
# 23     its too bad the doctors at the aid station did...
# 24                          stop looking at me like that
# 25     are you going to tell the marshal what those m...
# 26                       marshal aint doing shit william
# 27     first thing  mark im going to take you boys we...
# 28                        what are you going to do there
# 29         im going to tell hollander to make this right
# 30            im going to tell him to pay for a new barn
# ...                                                  ...
# 86348          unfortunately  he was killed this morning
# 86349  now both rings are in the open so the list is out
# 86350  someones contacted the major crime families of...
# 86351                                      diablo cartel
# 86352                                      tanaka yakuza
# 86353                                        ogrady clan
# 86354               was found dead at home in the valley
# 86355  angels  we need to get the halo rings back bef...
# 86356  well start at the caufield house see if that l...
# 86357  hey  charlie  we could really use bosleys help...
# 86358                 get to drive the racecar not today
# 86359                      blow up a castle not yet  bos
# 86360                   well  what do yall need me to do
# 86361                 read some body language hell  yeah
# 86362             im not going nowhere near no dead body
# 86363  freeze  ladies if youre not a dead body  other...
# 86364  we got a serious situation here my men have th...
# 86365          i have to ask you to evacuate immediately
# 86366  we got a 211  a 183  believe it or not  we got...
# 86367  an 11350 you found an illegal chinchilla ranch...
# 86368                              its a chinchilla farm
# 86369                                     but youre good
# 86370          negatory to orders to relinquish locality
# 86371                    circumspect to your observation
# 86372  well proceed to the interior of the dwelling w...
# 86373  well  i do not copy repeat  do not copy ill ha...
# 86374                              your sergeant is here
# 86375                                          hands off
# 86376  if you had your game faces on at the academy  ...
# 86377                                         simple caf
#
#                                                      Far
# ID
# 1                                             صداي خر خر
# 2                                                    پدر
# 3                                     شايد صداي باد باشه
# 4                                                     نه
# 5                دست نگه داريد خواهش ميکنم دست نگه داريد
# 6      اوانز تو فقط يک هفته وقت داري وگرنه خونتو خواه...
# 7                                                 ويليام
# 8                                         لعنتي ويليام 8
# 9                              لعنت به تو اونو بذار زمين
# 10                                              بذار برم
# 11                   اين آخرين علوفه اي بود که ما داشتيم
# 12                          من خودم اين کارو انجام ميدهم
# 13                                          نه تو نميکني
# 14       گله را آوردم بيرون الان تو برو اونجا را تميز کن
# 15                                 تو به من دروغ گفتي دن
# 16     تو به من گفتي قرضمونو به هلندر پرداخت کرديم ما...
# 17     خب پس تو فکر ميکني ما چطوري علوفه خريديم سه ما...
# 18     من فقط يک انتخاب بين خانوادم و پرداخت قرض اونا...
# 19                     ما قرار بود تصميماتو با هم بگيريم
# 20                         مگه تو تصميمه ديگه اي ميگرفتي
# 21     آليس مادوباره ميتونيم همه چي را دوباره جمع کني...
# 22     ما هم نميتونيم جلوي هلندر را از فروش زمينمون ب...
# 23     مشکل اينجاست که دکترها در درمانگاه کار زيادي ب...
# 24                                اينجوري به من نگاه نکن
# 25        تو ميخواي به مارشال بگي که اون آدما چيکار کردن
# 26                  مارشال هيچ کاري واسمون نميکنه ويليام
# 27     مارک اول اينکه من ميخوام شما پسرهارو با خودم ب...
# 28                             تو ميخواي اونجا چيکار کني
# 29                    من به هلندر ميگم که اينو درستش کنه
# 30                    من بهش ميگم پول يک اسطبل جديدو بده
# ...                                                  ...
# 86348                    متاسفانه اون امروز صبح كشته شده
# 86349  به اين ترتيب هردو انگشتر از دستمون در رفت بناب...
# 86350  يه نفر با جنايت كار بزرگ صحبت كرده تا ليست را ...
# 86351       خانواده جنايت كار ، انتونيوني ، ديابلو كارتر
# 86352                          تاناكا يازوكا ، اوگري كلن
# 86353         و يكي از شاهدان محافظت شده ما ، آلن كافيلد
# 86354                                ما جسدشو پيدا كرديم
# 86355  فرشته ها ، ما بايد انگشترهاي هيلو را پس بگيريم...
# 86356  كارمونو از خونه كافيلد شروع ميكنم شايد بتونه م...
# 86357  هي ، چارلي ، در اين مورد ميتونيم از كمك باسلي ...
# 86358               با ماشين مسابقه رانندگي كنم نه ، باس
# 86359                      يه قلعه را منفجر كنم نه ، باس
# 86360               خوب ، حالا ميشه بگيد بايد چه كار كنم
# 86361                            چند تا زبونو بخوني خوبه
# 86362                                   من پيش جسد نميرم
# 86363     آروم باشيد ، خانم ها ، اگه نميخوايد جسد ببينيد
# 86364  ما در موقعيت هستيم ، افراد من اين خيابون را مح...
# 86365             ازتون ميخوام هرچه سريعتر از اينجا بريد
# 86366           ما در موقعيت 35011 هستيم ، اصلا خوب نيست
# 86367                       موقعيت 35011مدركي پيدا كرديد
# 86368                                       يه مدرك كوچك
# 86369                                اما شماهم خوب هستيد
# 86370                        ترك كردن محل مخالف دستوراته
# 86371                                   با احتياط ببينيد
# 86372                 ما به همراه شما به داخل خونه ميريم
# 86373           خوب ، وايستيد ، بايد با گروهبان صحبت كنم
# 86374                             گروهبان شما همينجا هست
# 86375                                          دست نزنيد
# 86376          اگه شما هم توي دانشكده بوديد ، مي فهميديد
# 86377                                        اون خفه شده
#
# [86377 rows x 2 columns]

# %% [markdown]
# #### What Needs to Be Done Still
# - Figure out the encoding error for my data (I will be working on this over the weekend and will probably stop by Office Hours on Monday)
# - Finalize and execute search criteria.
# - POS-tag the sentences and process through shallow parser (Parsivar).
# - Analysis!
